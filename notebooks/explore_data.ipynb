# %%
# %load_ext autoreload
import pandas as pd

# %%
# Read test data
df = pd.read_csv('../data/sst/sst_test.txt', sep='\t', header=None,
                   names=['truth', 'text'],
                  )
df['truth'] = df['truth'].str.replace('__label__', '')
df['truth'] = df['truth'].astype(int).astype('category')
print(df.dtypes)
df.head()
# Out:
# truth    category
# text       object
# dtype: object
#   truth                                               text
# 0     3                     Effective but too-tepid biopic
# 1     4  If you sometimes like to go to the movies to h...
# 2     5  Emerges as something rare , an issue movie tha...
# 3     3  The film provides some great insight into the ...
# 4     5  Offers that rare combination of entertainment ...

# %% [markdown]
# ### FInd length of each text in the data

# %%
df['len'] = df['text'].str.len()
df.head()
# Out:
#   truth                                               text  len
# 0     3                     Effective but too-tepid biopic   30
# 1     4  If you sometimes like to go to the movies to h...   89
# 2     5  Emerges as something rare , an issue movie tha...  113
# 3     3  The film provides some great insight into the ...  138
# 4     5  Offers that rare combination of entertainment ...   61

# %% [markdown]
# ### Find shortest length text with rating of 1

# %%
df = df.sort_values(['len'], ascending=True)
df[df['truth'] == 1].head(50)
# Out:
#      truth                                               text  len
# 1668     1                                       Ridiculous .   12
# 2154     1                                    It 's painful .   15
# 1593     1                                   A real clunker .   16
# 1504     1                                   Extremely dumb .   16
# 1463     1                                  A very bad sign .   17
# 1506     1                                 Extremely boring .   18
# 1171     1                             So what is the point ?   22
# 2088     1                          Do n't waste your money .   25
# 1306     1                          A sour , nasty offering .   25
# 1081     1                          The ending is a cop-out .   25
# 1511     1                         How did it ever get made ?   26
# 2209     1                        ( U ) nrelentingly stupid .   27
# 1226     1                       It 's just incredibly dull .   28
# 1210     1                       I hated every minute of it .   28
# 1181     1                       B. ) That sure is pathetic !   28
# 1326     1                     A waste of good performances .   30
# 1074     1                     The film seems a dead weight .   30
# 1095     1                     This one 's weaker than most .   30
# 1389     1                     A dreadful live-action movie .   30
# 1192     1                     Lame , haphazard teen comedy .   30
# 1364     1                  Godawful boring slug of a movie .   33
# 1756     1                  Madonna still ca n't act a lick .   33
# 1393     1                  All I can say is fuhgeddaboutit .   33
# 1566     1                  Made by jackasses for jackasses .   33
# 2144     1                It 's an awfully derivative story .   35
# 2128     1               The story ... is moldy and obvious .   36
# 1036     1              It took 19 predecessors to get THIS ?   37
# 2110     1              The movie makes absolutely no sense .   37
# 1545     1              Nothing more than a mediocre trifle .   37
# 1617     1             Now it 's a bad , embarrassing movie .   38
# 1955     1             Ecks this one off your must-see list .   38
# 1875     1             ... has virtually no script at all ...   38
# 1303     1           Not even the Hanson Brothers can save it   40
# 1421     1          Scotland , Pa. is a strangely drab romp .   41
# 1621     1        Wait for video -- and then do n't rent it .   43
# 1485     1      It 's not horrible , just horribly mediocre .   45
# 1799     1     Filmmakers have to dig deep to sink this low .   46
# 1162     1     After that , it just gets stupid and maudlin .   46
# 1965     1     This is n't a `` Friday '' worth waiting for .   46
# 1652     1    Flaccid drama and exasperatingly slow journey .   47
# 2146     1    About as cutting-edge as Pet Rock : The Movie .   47
# 1481     1   Even the unwatchable Soapdish is more original .   48
# 1349     1  This time Kaufman 's imagination has failed him .   49
# 1339     1  Lacks heart , depth and , most of all , purpose .   49
# 1523     1  The plot grinds on with yawn-provoking dullness .   49
# 2161     1  Unfortunately , the picture failed to capture ...   50
# 1251     1  You 'll be more entertained getting hit by a b...   50
# 1609     1  An instant candidate for worst movie of the ye...   50
# 1884     1  Bad beyond belief and ridiculous beyond descri...   53
# 1440     1  Better at putting you to sleep than a sound ma...   53
